# %% [markdown]
# <a href="https://colab.research.google.com/github/lcfox27/Distro/blob/main/RevisedDistro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""income_distribution_analysis.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1p6jG6vL9M3b5z4Z3h5n3R2R5p9Y3q9w7
"""
# Install camelot-py and its dependencies
# !pip install camelot-py[cv]
# !sudo apt-get update
# !sudo apt-get install -y ghostscript python3-tk
# !pip install PyPDF2
# !pip install scikit-learn
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install requests
# !pip install io
# !pip install IPython

from IPython import get_ipython
from IPython.display import display

# %%
import matplotlib.pyplot as plt
import pandas as pd
import camelot
import requests
from io import BytesIO
import PyPDF2
from sklearn.linear_model import LinearRegression
import numpy as np # Import numpy for numerical operations

# --- Step 1: PDF Data Extraction and Formatting (Refined) ---

# Download the PDF file once
url = "https://eml.berkeley.edu/~webfac/cromer/e211_f12/LindertWilliamson.pdf"
response = requests.get(url)
pdf_data = BytesIO(response.content)

# Determine the actual number of pages in the PDF
reader = PyPDF2.PdfReader(pdf_data)
num_pages = len(reader.pages)

# --- Function to extract and format tables ---
def extract_and_format_table(pdf_data, page_number, table_areas=None):
    """
    Extracts and formats a table from a PDF using camelot.

    Args:
        pdf_data: BytesIO object containing the PDF data.
        page_number: The page number to extract the table from.
        table_areas: List of table areas to extract (e.g., ["x1,y1,x2,y2"]).

    Returns:
        A pandas DataFrame containing the extracted and formatted table,
        or an empty DataFrame if extraction fails or the table is empty.
    """
    try:
        tables = camelot.read_pdf(
            pdf_data, pages=str(page_number), flavor="stream", table_areas=table_areas
        )

        if not tables or tables[0].df.empty:
            print(f"Warning: No table found or table is empty on page {page_number} within specified areas.")
            return pd.DataFrame()

        df = tables[0].df.copy() # Work on a copy to avoid modifying the original

        # Clean headers and set index
        if not df.empty:
            # Explicitly convert the first row to string type before stripping
            # This handles cases where Camelot might interpret header cells as numeric
            df.iloc[0] = df.iloc[0].astype(str).str.strip()
            df.columns = df.iloc[0]  # Set the first row as column names
            df = df[1:].reset_index(drop=True)  # Remove the first row and reset index

            if not df.empty and len(df.columns) > 0:
                 # Check if the first column is suitable as an index
                 # (e.g., contains unique values that can be used as identifiers)
                 if df.iloc[:, 0].nunique() == len(df): # Check for uniqueness
                      df = df.set_index(df.columns[0])
                 else:
                      print(f"Warning: First column on page {page_number} does not have unique values. Cannot set as index.")
                      # Keep the first column as a regular column
            else:
                 print(f"Warning: DataFrame is empty or has no columns after header processing on page {page_number}.")
                 return pd.DataFrame() # Return empty if issues

        # Convert to numeric using a more robust approach
        def convert_to_numeric(x):
            if isinstance(x, str):
                try:
                    # Remove '%' and any leading/trailing whitespace
                    return pd.to_numeric(x.replace("%", "").strip())
                except (ValueError, AttributeError):
                    return np.nan # Use NaN for errors
            # Handle non-string types gracefully by attempting direct conversion
            # or returning NaN if conversion fails
            try:
                 return pd.to_numeric(x)
            except (ValueError, TypeError):
                 return np.nan


        # Apply numeric conversion to all columns
        # Only apply to columns that are expected to be numeric (e.g., wealth classes)
        # or apply to all columns and handle errors gracefully as done in convert_to_numeric
        for col in df.columns:
             df[col] = df[col].apply(convert_to_numeric)


        return df

    except Exception as e:
        print(f"Error extracting table from page {page_number}: {e}")
        return pd.DataFrame()  # Return empty DataFrame in case of error

        # Convert to numeric using a more robust approach
        def convert_to_numeric(x):
            if isinstance(x, str):
                try:
                    # Remove '%' and any leading/trailing whitespace
                    return pd.to_numeric(x.replace("%", "").strip())
                except (ValueError, AttributeError):
                    return np.nan # Use NaN for errors
            # Handle non-string types gracefully by attempting direct conversion
            # or returning NaN if conversion fails
            try:
                 return pd.to_numeric(x)
            except (ValueError, TypeError):
                 return np.nan


        # Apply numeric conversion to all columns
        # Only apply to columns that are expected to be numeric (e.g., wealth classes)
        # or apply to all columns and handle errors gracefully as done in convert_to_numeric
        for col in df.columns:
             df[col] = df[col].apply(convert_to_numeric)


        return df

    except Exception as e:
        print(f"Error extracting table from page {page_number}: {e}")
        return pd.DataFrame()  # Return empty DataFrame in case of error

# --- Extract tables with adjusted table_areas (Identify relevant tables from your PDF exploration) ---
# Based on your prior exploration, identify which tables contain income distribution data over time
# You might need to adjust the page numbers and table_areas based on your PDF's structure.
table_specs = {
    # Example: Assuming a table with time series data on page 26 in a certain area
    # You will need to refine these based on which tables in the PDF actually contain the data you want to integrate.
    "PDF_Table_1": {"page": 26, "areas": ["30,350,560,680"]}, # Example area - ADJUST AS NEEDED
    "PDF_Table_2": {"page": 27, "areas": ["30,370,560,670"]}, # Example area - ADJUST AS NEEDED
    # Add more tables if they contain relevant time-series income distribution data
}

pdf_tables_data = {}
for table_name, spec in table_specs.items():
    df = extract_and_format_table(
        pdf_data, spec["page"], spec["areas"]
    )
    if not df.empty:
        pdf_tables_data[table_name] = df
        print(f"\nSuccessfully extracted and formatted: {table_name}")
        display(df.head())
    else:
        print(f"\nFailed to extract or table is empty: {table_name}")

# %%
# --- Step 2: Prepare Excel/Google Sheet Data ---

# Load data from the Excel file (Assuming it's already exported to 'data2.xlsx')
# You can also integrate code to download directly from Google Sheets if needed

# Define expected standardized names for wealth classes
standardized_wealth_classes = ["Bottom 50%", "50.1-90%", "90.1-99%", "99-99.9%", "99.99-100%"]

try:
    df_excel = pd.read_excel('data2.xlsx')
    print("\nSuccessfully loaded data from 'data2.xlsx':")
    display(df_excel.head())

    # --- Step 3: Standardize and Clean Data (Excel Data) ---
    # Rename the year column to 'Year' if it's not already named that
    # Assuming the year column is the first column or has a specific name
    # ADJUST THE COLUMN NAME 'OriginalYearColumnName' to match your Excel file
    if df_excel.columns[0] != 'Year':
        df_excel = df_excel.rename(columns={df_excel.columns[0]: 'Year'})
        print("Renamed year column in df_excel to 'Year'.")

    # Convert 'Year' column to numeric, coercing errors
    df_excel['Year'] = pd.to_numeric(df_excel['Year'], errors='coerce')
    # Drop rows where Year is NaN after conversion
    df_excel.dropna(subset=['Year'], inplace=True)
    # Convert Year to integer if appropriate
    df_excel['Year'] = df_excel['Year'].astype(int)

    # Standardize wealth class column names in df_excel
    # Create a mapping from your Excel column names to the desired standardized names
    # ADJUST THIS MAPPING based on your Excel file's column names
    wealth_class_mapping = {
        "Excel_Bottom_50_Col": "Bottom 50%",
        "Excel_50_90_Col": "50.1-90%",
        "Excel_90_99_Col": "90.1-99%",
        "Excel_99_999_Col": "99-99.9%",
        "Excel_9999_100_Col": "99.99-100%",
        # Add other mappings as needed
    }
    # Only attempt to rename if the columns actually exist in the DataFrame
    columns_to_rename = {k: v for k, v in wealth_class_mapping.items() if k in df_excel.columns}
    df_excel = df_excel.rename(columns=columns_to_rename)
    print("Standardized wealth class column names in df_excel.")

    # Convert income share columns to numeric
    for col in standardized_wealth_classes:
        if col in df_excel.columns:
             # Remove '%' and convert to numeric, coercing errors
             df_excel[col] = pd.to_numeric(df_excel[col].astype(str).str.replace('%', '', regex=False).strip(), errors='coerce')
             # Replace negative values with NaN if income share cannot be negative
             df_excel[col] = df_excel[col].apply(lambda x: x if x >= 0 else np.nan)

    print("Cleaned and converted columns in df_excel.")
    display(df_excel.head())

except FileNotFoundError:
    print("Error: 'data2.xlsx' not found. Please ensure the Google Sheet has been exported and the file is in the correct location.")
    df_excel = pd.DataFrame() # Create an empty DataFrame to avoid further errors
except Exception as e:
    print(f"An error occurred while reading or processing the Excel file: {e}")
    df_excel = pd.DataFrame()

# --- Create a dummy df_excel if loading fails for demonstration ---
# In a real scenario, you would remove this dummy data part
if df_excel.empty:
    print("\nUsing dummy df_excel data for demonstration.")
    data_excel = {'Year': [1850, 1900, 1950, 2000],
                'Bottom 50%': [25, 20, 18, 15],
                '50.1-90%': [30, 32, 34, 36],
                '90.1-99%': [35, 40, 42, 45],
                '99-99.9%': [40, 45, 50, 55],
                '99.99-100%': [10, 8, 6, 4]}
    df_excel = pd.DataFrame(data_excel)

    # --- Step 3: Standardize and Clean Data (Excel Data) ---
    # Rename the year column to 'Year' if it's not already named that
    # Assuming the year column is the first column or has a specific name
    if df_excel.columns[0] != 'Year':
        df_excel = df_excel.rename(columns={df_excel.columns[0]: 'Year'})
        print("Renamed year column in df_excel to 'Year'.")

    # Convert 'Year' column to numeric, coercing errors
    df_excel['Year'] = pd.to_numeric(df_excel['Year'], errors='coerce')
    # Drop rows where Year is NaN after conversion
    df_excel.dropna(subset=['Year'], inplace=True)
    # Convert Year to integer if appropriate
    df_excel['Year'] = df_excel['Year'].astype(int)

    # Standardize wealth class column names in df_excel
    # Create a mapping from your Excel column names to the desired standardized names
    wealth_class_mapping = {
        "Excel_Bottom_50_Col": "Bottom 50%",
        "Excel_50_90_Col": "50.1-90%",
        "Excel_90_99_Col": "90.1-99%",
        "Excel_99_999_Col": "99-99.9%",
        "Excel_9999_100_Col": "99.99-100%",
        # Add other mappings as needed
    }
    # Only attempt to rename if the columns actually exist in the DataFrame
    columns_to_rename = {k: v for k, v in wealth_class_mapping.items() if k in df_excel.columns}
    df_excel = df_excel.rename(columns=columns_to_rename)
    print("Standardized wealth class column names in df_excel.")


    # Convert income share columns to numeric
    standardized_wealth_classes = ["Bottom 50%", "50.1-90%", "90.1-99%", "99-99.9%", "99.99-100%"] # Define expected standardized names
    for col in standardized_wealth_classes:
        if col in df_excel.columns:
             # Remove '%' and convert to numeric, coercing errors
             # Apply .str.strip() to remove whitespace after replacing '%'
             df_excel[col] = pd.to_numeric(df_excel[col].astype(str).str.replace('%', '', regex=False).str.strip(), errors='coerce')
             # Replace negative values with NaN if income share cannot be negative
             df_excel[col] = df_excel[col].apply(lambda x: x if x >= 0 else np.nan)

    print("Cleaned and converted columns in df_excel.")
    display(df_excel.head())


# --- Step 3: Standardize and Clean Data (PDF DataFrames) ---

# Standardize and clean the extracted PDF DataFrames
# You need to inspect the extracted DataFrames (pdf_tables_data) and apply cleaning
# based on their structure and column names.
cleaned_pdf_dfs = {}
for table_name, df in pdf_tables_data.items():
    if not df.empty:
        print(f"\nCleaning {table_name}...")
        df_cleaned = df.copy()

        # Assuming the index is the 'Year' for these tables after formatting
        # Ensure the index is named 'Year' and is of integer type
        if df_cleaned.index.name != 'Year':
             df_cleaned.index.name = 'Year'
        try:
            df_cleaned.index = df_cleaned.index.astype(int)
        except ValueError:
             print(f"Warning: Could not convert index of {table_name} to integer.")
             # Handle this case, perhaps by inspecting the index values

        # Standardize wealth class column names in PDF DataFrames
        # This is a placeholder - YOU NEED TO ADJUST THIS MAPPING based on the
        # actual column names extracted by camelot for each PDF table.
        pdf_wealth_class_mapping = {
            "PDF_Bottom_50_Col": "Bottom 50%",
            "PDF_50_90_Col": "50.1-90%",
            "PDF_90_99_Col": "90.1-99%",
            "PDF_99_999_Col": "99-99.9%",
            "PDF_9999_100_Col": "99.99-100%",
             # Add other mappings specific to your PDF tables
        }
        df_cleaned = df_cleaned.rename(columns=pdf_wealth_class_mapping)
        print(f"Standardized wealth class column names in {table_name}.")

        # Convert income share columns to numeric (already attempted in the function, but double-check)
        for col in df_cleaned.columns:
            if col in standardized_wealth_classes: # Only process known wealth class columns
                 # Ensure these columns are numeric, coercing errors
                 df_cleaned[col] = pd.to_numeric(df_cleaned[col], errors='coerce')
                 # Replace negative values with NaN
                 df_cleaned[col] = df_cleaned[col].apply(lambda x: x if x >= 0 else np.nan)


        cleaned_pdf_dfs[table_name] = df_cleaned
        display(df_cleaned.head())
    else:
        print(f"\nSkipping cleaning for empty table: {table_name}")

# --- Step 4: Merge DataFrames ---

# Start with the Excel DataFrame or an empty DataFrame if Excel loading failed
if not df_excel.empty:
    merged_df = df_excel.copy()
    print("\nStarting merge with df_excel.")
else:
    merged_df = pd.DataFrame(columns=['Year'] + standardized_wealth_classes)
    print("\nStarting merge with an empty DataFrame as df_excel is empty.")

# Merge with cleaned PDF DataFrames
for table_name, df_pdf in cleaned_pdf_dfs.items():
    if not df_pdf.empty:
         # Ensure 'Year' is a column in the PDF DataFrame for merging
         if df_pdf.index.name == 'Year':
             df_pdf_reset = df_pdf.reset_index()
         else:
             df_pdf_reset = df_pdf.copy()
             print(f"Warning: {table_name} does not have 'Year' as index. Skipping merge.")
             continue # Skip merge for this PDF table

         # Perform the merge
         # Use an outer merge to keep all years from all data sources
         merged_df = pd.merge(merged_df, df_pdf_reset, on='Year', how='outer', suffixes=('', f'_{table_name}'))
         print(f"Merged with {table_name}.")
         display(merged_df.head())

# --- Step 5: Fill Missing Values ---

# Ensure 'Year' is the index for filling operations
if 'Year' in merged_df.columns:
     merged_df = merged_df.set_index('Year').sort_index()
     print("\nSet 'Year' as index for filling missing values.")

# Fill missing values using linear interpolation
# Interpolate only the wealth class columns
for col in standardized_wealth_classes:
    if col in merged_df.columns:
        merged_df[col] = merged_df[col].interpolate(method='linear')
        print(f"Interpolated missing values for column: {col}")

# Optional: Fill any remaining NaNs (e.g., at the start/end) using forward/backward fill
merged_df = merged_df.fillna(method='ffill').fillna(method='bfill')
print("Filled remaining NaNs using forward/backward fill.")

print("\nDataFrame after merging and filling missing values:")
display(merged_df.head())
print("\nDataFrame info after merging and filling:")
merged_df.info()

# --- Step 6: Visualize Integrated Data (Stacked Area Chart) ---

# Ensure the DataFrame is ready for plotting
# Select only the standardized wealth class columns for plotting
plot_df = merged_df[standardized_wealth_classes].copy()

# Drop rows where all wealth class values are NaN (if any remain)
plot_df.dropna(how='all', inplace=True)

# Drop the '0%' column if it exists and is not needed for plotting
if '0%' in plot_df.columns:
    plot_df = plot_df.drop(columns=['0%'])
    print("Dropped '0%' column from plot_df.")

# Define the order of wealth classes for the legend and stacking
# Ensure these columns exist in your plot_df before plotting
plot_wealth_classes = [col for col in standardized_wealth_classes if col in plot_df.columns]

if not plot_df.empty and plot_wealth_classes:
    plt.figure(figsize=(12, 7))
    plt.stackplot(
        plot_df.index,
        [plot_df[wc] for wc in plot_wealth_classes],
        labels=plot_wealth_classes,
        alpha=0.8,
    )

    # Add labels, legend, and title
    plt.title("Income Distribution Over Time (Integrated Data)", fontsize=16)
    plt.xlabel("Year", fontsize=12)
    plt.ylabel("Income Share (%)", fontsize=12)
    plt.legend(loc="upper left", title="Wealth Classes")
    plt.grid(axis="y", linestyle="--", alpha=0.7)
    plt.tight_layout()

    # Show the plot
    plt.show()
else:
    print("\nNo data available for plotting after merging and cleaning.")

# --- Step 7: Perform Analysis (Example) ---

# You can now perform analysis on the 'merged_df' DataFrame
# Examples:
# - Calculate summary statistics for each wealth class over time
# - Analyze the trend of a specific wealth class
# - Calculate income inequality metrics (e.g., Gini coefficient - requires more data/calculation)

print("\nBasic Analysis:")
print(merged_df.describe())

# Example: Plotting the trend of a single wealth class
# if 'Bottom 50%' in merged_df.columns:
#     plt.figure(figsize=(10, 6))
#     merged_df['Bottom 50%'].plot()
#     plt.title("Trend of Bottom 50% Income Share", fontsize=14)
#     plt.xlabel("Year", fontsize=12)
#     plt.ylabel("Income Share (%)", fontsize=12)
#     plt.grid(True)
#     plt.show()
# Out:
# ...
# WARNING: camelot-py 1.0.0 does not provide the extra 'cv'
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...
